# %%
import urllib
import urllib.request
from bs4 import BeautifulSoup
import os

# %%
def make_soup(url):
    thepage = urllib.request.urlopen(url)
    soupdata = BeautifulSoup(thepage, "html.parser")
    return soupdata

# %%
playerdatasaved = ""
soup = make_soup("https://www.basketball-reference.com/players/w/walkeke02/gamelog/2020/")

for record in soup.findAll('tr'):
    playerdata = ""
    for data in record.findAll('td'):
        playerdata = playerdata + "," + data.text
    if len(playerdata)!=0:
        playerdatasaved = playerdatasaved + "\n" + playerdata[1:]

# %%
print(playerdatasaved)
# Out:
# 10-192
# 20-2912
# 30-3931
# 40+1
# ,10-19,2,20-29,12,30-39,31,40+,1
# 10-19,2
# 20-29,12
# 30-39,31
# 40+,1
#  0-94
# 10-1917
# 20-2915
# 30-398
# 40-492
# , 0-9,4,10-19,17,20-29,15,30-39,8,40-49,2
#  0-9,4
# 10-19,17
# 20-29,15
# 30-39,8
# 40-49,2
#  0-427
#  5-918
# 10-141
# , 0-4,27, 5-9,18,10-14,1
#  0-4,27
#  5-9,18
# 10-14,1
#  0-422
#  5-922
# 10-142
# , 0-4,22, 5-9,22,10-14,2
#  0-4,22
#  5-9,22
# 10-14,2
# 017
# 1-227
# 3-42
# ,0,17,1-2,27,3-4,2
# 0,17
# 1-2,27
# 3-4,2
# 027
# 1-219
# ,0,27,1-2,19
# 0,27
# 1-2,19
# 09
# 1-229
# 3-47
# 51
# ,0,9,1-2,29,3-4,7,5,1
# 0,9
# 1-2,29
# 3-4,7
# 5,1
# 1,2019-10-23,29-168,BOS,@,PHI,L (-14),1,34:15,4,18,.222,1,6,.167,3,4,.750,2,0,2,2,0,0,3,4,12,-1.2,-16
# 2,2019-10-25,29-170,BOS,,TOR,W (+6),1,36:13,8,22,.364,2,8,.250,4,4,1.000,3,3,6,2,2,2,2,3,22,14.4,+7
# 3,2019-10-26,29-171,BOS,@,NYK,W (+23),1,30:21,11,17,.647,7,12,.583,3,4,.750,3,3,6,4,2,0,0,2,32,31.1,+13
# ...

# %%
filename = "NBA_player_stats.csv"
file = open(filename, "w")
file.write(playerdatasaved)

# %%
#"Rk,G,Date,Age,Tm,Opp,GS,MP,FG,FGA,FG%,3P,3PA,3P%,FT,FTA,FT%,ORB,DRB,TRB,AST,STL,BLK,TOV,PF,PTS,GmSc,+/-\n"
